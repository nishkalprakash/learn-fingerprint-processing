# %% [markdown]
# # **Milestone 1 - Basics**

# %% [markdown]
# This section contains tasks that will help you get familiar with the basics of image processing.
#
# You may add more code and markdown cells as needed

# %% [markdown]
# ## TASK 1
# * Load a 512x512 image
# * Initialize with random rgb values
# * Display it

# %% [markdown]
# #### Importing the libraries

# %%
## Hint:load opencv and numpy
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
from numpy import array
# from skimage.morphology import skeletonize
# img=cv.imread('101_1.tif')
# print(img)

# %% [markdown]
# #### Define the variables to store a 3d matrix for the image

# %%
## Hint: use numpy
import numpy as np
S=np.random.randint(0, 255, size=(512,512,3))


print(S)
# Out:
# [[[253 129 225]
#   [233 150  36]
#   [125  51 211]
#   ...
#   [ 28 101 234]
#   [ 57 239  62]
#   [  6  46 154]]
#
#  [[  4 149 122]
#   [ 70 125  15]
#   [135 181  79]
#   ...
#   [ 34  70  15]
#   [226 140 162]
#   [180   8 177]]
#
#  [[112 134  80]
#   [ 71  98  50]
#   [102 248 205]
#   ...
#   [ 97 201  82]
#   [237 165 174]
#   [234  48 198]]
#
#  ...
#
#  [[ 65 211  12]
#   [ 80 216 108]
#   [ 74  42 232]
#   ...
#   [221 170 126]
#   [148 222  88]
#   [144  25 236]]
#
#  [[ 84 177 103]
#   [118  20 195]
#   [123 115 209]
#   ...
#   [179 119  13]
#   [122  94  13]
#   [199 112 218]]
#
#  [[242  73  26]
#   [ 66  18  67]
#   [121 113  34]
#   ...
#   [205 101 228]
#   [143 173  93]
#   [104 195 251]]]

# %% [markdown]
# #### Initialize the matrix with random rgb values

# %%
## Hint: use random package
S

# %% [markdown]
# #### Display the random image

# %%
## Hint: use matplotlib
plt.imshow(S)

# %% [markdown]
# ## TASK 2
#
# * Load a 512x512 image
# * Initialize with random rgb values
# * Tranform the image into a grayscale image
# * Display it

# %% [markdown]
# #### Convert `TASK 1` Image to corresponding grayscale image
# (without using any inbuilt function of `opencv`)

# %%
## Hint: use the variable from TASK 1
# Out:
# [[0.54379085 0.78039216 0.48627451 0.30718954 0.39607843 0.24836601
#   0.07058824 0.4379085  0.46143791 0.50849673 0.55555556 0.50457516
#   0.61699346 0.4379085  0.46797386 0.48496732 0.46013072 0.62352941
#   0.45620915 0.36993464]
#  [0.74248366 0.39607843 0.49542484 0.23921569 0.12026144 0.38823529
#   0.33333333 0.17124183 0.72156863 0.68496732 0.39607843 0.69542484
#   0.06797386 0.60130719 0.49411765 0.62352941 0.52026144 0.69150327
#   0.44052288 0.60915033]
#  [0.60522876 0.7372549  0.39738562 0.51372549 0.81176471 0.49673203
#   0.45098039 0.55947712 0.55947712 0.72026144 0.72810458 0.48235294
#   0.39738562 0.61176471 0.18431373 0.33333333 0.65490196 0.49150327
#   0.67973856 0.34640523]
#   0.46928105 0.50849673 0.41045752 0.68104575 0.59477124 0.40261438
#   0.40653595 0.29150327 0.53986928 0.65490196 0.70588235 0.32287582
#   0.4496732  0.68496732]
#  [0.50980392 0.48104575 0.43006536 0.54509804 0.61176471 0.57777778
#   0.45359477 0.52156863 0.71503268 0.10196078 0.72156863 0.55555556
#   0.70196078 0.48496732 0.52287582 0.65228758 0.76862745 0.36993464
#   0.58039216 0.44313725]
#  [0.55686275 0.79215686 0.57647059 0.6        0.48104575 0.40915033
#   0.57254902 0.5620915  0.47973856 0.43921569 0.72418301 0.25359477
#   0.52941176 0.78562092 0.48627451 0.45620915 0.31111111 0.2496732
#   0.32026144 0.56078431]
#  [0.55947712 0.47843137 0.33594771 0.84836601 0.23006536 0.69934641
#   0.50849673 0.43921569 0.70457516 0.22745098 0.57385621 0.35947712
#   0.65490196 0.74509804 0.48627451 0.54509804 0.69281046 0.58431373
#   0.61568627 0.70457516]
#  [0.2627451  0.27320261 0.45228758 0.49281046 0.59084967 0.47581699
#   0.41437908 0.58954248 0.76339869 0.5503268  0.24313725 0.92679739
#   0.64052288 0.4        0.2496732  0.77254902 0.70718954 0.65751634
#   0.56993464 0.39346405]
#  [0.07843137 0.62614379 0.57647059 0.20522876 0.60784314 0.57254902
#   0.54771242 0.35947712 0.37254902 0.58169935 0.44836601 0.41568627
#   0.80130719 0.52156863 0.7254902  0.61437908 0.51633987 0.41437908
#   0.40522876 0.85490196]
#  [0.30196078 0.64183007 0.36732026 0.69673203 0.34771242 0.48235294
#   0.59215686 0.54509804 0.46535948 0.40522876 0.35163399 0.51503268
#   0.47320261 0.46666667 0.53333333 0.57385621 0.6248366  0.4130719
#   0.27843137 0.45098039]]

# %% [markdown]
# #### Display the grayscale image

# %%
## Hint: use matplotlib
plt.imshow(S)
(row, col) = S.shape[0:2]
print(row,col)
# Take the average of pixel values of the BGR Channels
# to convert the colored image to grayscale image
for i in range(row):
    for j in range(col):
        # Find the average of the BGR pixel values
         r,g,b = S[i][j]
         S[i][j]=(r+g+b)/3
        

    # S[i][j] = 0.2989 * r + 0.5870 * g + 0.1140 * b


    
plt.imshow(S)
# Out:
# 512 512

# %% [markdown]
# ## TASK 3
# * Load the Fingerprint Image `datasets\task3\1.tiff`
# * Display it
# * Load the Fingerprint Image `datasets\task3\2.tiff`
# * Display it

# %% [markdown]
# #### Load the Fingerprint Image `datasets\task3\1.tiff`

# %%
## Hint: use opencv

# %% [markdown]
# #### Display the First Fingerprint image

# %%
## Hint: use matplotlib

# %% [markdown]
# #### Load the Fingerprint Image `datasets\task3\2.tiff`

# %%
## Hint: use opencv

# %% [markdown]
# #### Display the Second Fingerprint image

# %%
## Hint: use matplotlib
